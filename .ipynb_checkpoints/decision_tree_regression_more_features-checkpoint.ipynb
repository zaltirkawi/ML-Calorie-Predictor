# %%
# Importing preprocessed dataset
import pandas as pd
df = pd.read_csv('cleaned_data_more_features_filtered.csv')

# %%
#Separating features X from labels y
y = df['calories'].to_numpy()
X = df.drop(columns=['calories']).to_numpy()

# %%
# Scaling the data and dividing dataset into training and testing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X_scaled,y, test_size = 0.2)

# %%
from sklearn.tree import DecisionTreeRegressor
DTR = DecisionTreeRegressor(max_depth = 4)
DTR.fit(X_train, y_train)
DTR.score(X_test, y_test) #testing accuracy
# Out:
# 0.8987116269869808

# %%
DTR.score(X_train, y_train) #training accuracy
# Out:
# 0.9065626171560607

# %%
#X_test = scaler.transform(X)
y_pred = DTR.predict(X_test)
y_pred
# Out:
# array([ 433.41233278,  433.41233278,  206.78506513, ..., 1136.89971347,
#         623.4860386 ,  206.78506513])

# %%
print(y_test)
# Out:
# [ 409.5  222.   361.4 ... 1281.2  441.6  213.4]

# %%
print(X)
# Out:
# [[  0  13   0 ...  55  11   7]
#  [ 18   0  17 ...  30   9   6]
#  [ 22  32  48 ... 130   6  13]
#  ...
#  [  6   2   3 ...  40   7   8]
#  [ 11  57  11 ...  29   9  10]
#  [ 14  33   4 ...  20   5   7]]

# %%
import numpy as np

# Creating a sample input
sample_input = np.array([22, 32, 48, 39, 27, 5, 130, 6, 13]) #This is the same as the third sample, so we're expecting something close to 269.8 calories

# Reshaping (1, num_features)
sample_input = sample_input.reshape(1, -1)

sample_input_scaled = scaler.transform(sample_input)  # Use the same scaler from training

# Making prediction
predicted_value = DTR.predict(sample_input_scaled)

print("Predicted Calories:", predicted_value)
# Out:
# Predicted Calories: [206.78506513]

# %%
# Plotting linear regression between each nutrtional value and the calories
from matplotlib import pyplot as plt
for i in range(9):
    feature_index = i
    
    # Splitting using single feature
    X_single = X[:, feature_index].reshape(-1, 1)
    single_scaler = StandardScaler()
    X_single_scaled = single_scaler.fit_transform(X_single)
    X_train_single, X_test_single, y_train_single, y_test_single = train_test_split(X_single_scaled,y, test_size = 0.2)
    
    # Fitting model using only one feature
    DTR_single = DecisionTreeRegressor(max_depth = 4)
    DTR_single.fit(X_train_single, y_train_single)
    
    y_pred_single = DTR_single.predict(X_test_single)
    
    # Plotting the actual data points
    #plt.scatter(X_single, y, color='b', label="Actual data")
    plt.plot(X_test_single, y_test_single, color='b', marker=".", markersize=5, linewidth=0, label="Actual data")    
    # Plotting the regression line
    plt.plot(X_test_single, y_pred_single, color='k', linewidth=0.5, label="Regression line")

    # Getting the feature names from the data
    feature_names = df.drop(columns=['calories']).columns
    feature_name = feature_names[feature_index]
    
    plt.xlabel(feature_name)
    plt.ylabel("Calories")
    plt.legend()
    plt.title(f"Decision Tree Regression on {feature_name}")
    plt.show()

# %%
# Evaluation metrics
from sklearn.metrics import mean_absolute_error,mean_squared_error,root_mean_squared_error,r2_score
mae = mean_absolute_error(y_test, y_pred) 
mse = mean_squared_error(y_test, y_pred)
rmse = root_mean_squared_error(y_test, y_pred) 
r2 = r2_score(y_test, y_pred) 
  
print("MAE:", mae) 
print("MSE:", mse) 
print("RMSE:", rmse)
print("r2:", r2)
# Out:
# MAE: 128.0759109980984
# MSE: 46691.88145585541
# RMSE: 216.083042962319
# r2: 0.8987116269869808

# %%
#cross validation
from sklearn.model_selection import cross_val_score
scores = cross_val_score(DTR, X, y, cv=5) #X and y will be split into folds
(scores)
# Out:
# array([0.90182699, 0.90462777, 0.90011586, 0.89939343, 0.89321527])

# %%
from sklearn.model_selection import cross_validate #more comprehensive: gives time, can show training scores, can show results for multiple metrics
scores = cross_validate(DTR, X, y, cv=5, return_train_score= True, scoring=('r2', 'neg_root_mean_squared_error','neg_mean_absolute_error','neg_mean_squared_error')) #X and y will be split into folds
print(scores)
# Out:
# {'fit_time': array([0.45707226, 0.45111632, 0.45237589, 0.45191693, 0.44282937]), 'score_time': array([0.00810909, 0.01015639, 0.0101335 , 0.01018834, 0.00207281]), 'test_r2': array([0.90182699, 0.90462777, 0.90011586, 0.89939343, 0.89321527]), 'train_r2': array([0.90629898, 0.90600012, 0.90687428, 0.90413144, 0.90876867]), 'test_neg_root_mean_squared_error': array([-214.60817188, -217.85981125, -213.28726481, -223.64851044,
#        -207.14946383]), 'train_neg_root_mean_squared_error': array([-208.34553355, -207.0848166 , -208.48439658, -209.14796943,
#        -209.25595972]), 'test_neg_mean_absolute_error': array([-128.94459152, -128.73947545, -128.29859036, -130.43575105,
#        -124.94663956]), 'train_neg_mean_absolute_error': array([-126.67799743, -127.62882437, -126.82048643, -127.58705908,
#        -128.29849802]), 'test_neg_mean_squared_error': array([-46056.66743674, -47462.89735669, -45491.45733038, -50018.65622291,
#        -42910.90036498]), 'train_neg_mean_squared_error': array([-43407.86134916, -42884.12126513, -43465.74361802, -43742.87311856,
#        -43788.05667994])}

# %%
scores_df = pd.DataFrame(scores)
summary_df = scores_df.mean().to_frame(name="Mean")
summary_df["Std Dev"] = scores_df.std()
print(summary_df)
# Out:
#                                            Mean      Std Dev
# fit_time                               0.451062     0.005157
# score_time                             0.008132     0.003502
# test_r2                                0.899836     0.004214
# train_r2                               0.906415     0.001670
# test_neg_root_mean_squared_error    -215.310644     6.066520
# train_neg_root_mean_squared_error   -208.463735     0.867700
# test_neg_mean_absolute_error        -128.273010     2.025553
# train_neg_mean_absolute_error       -127.402573     0.661767
# test_neg_mean_squared_error       -46388.115742  2614.424448
# train_neg_mean_squared_error      -43457.731206   361.247974

# %%
from sklearn import tree
tree.plot_tree(DTR)
# Out:
# [Text(0.5, 0.9, 'x[0] <= 2.263\nsquared_error = 465386.223\nsamples = 185288\nvalue = 469.609'),
#  Text(0.25, 0.7, 'x[5] <= 1.386\nsquared_error = 136628.429\nsamples = 180830\nvalue = 394.709'),
#  Text(0.375, 0.8, 'True  '),
#  Text(0.125, 0.5, 'x[0] <= 0.105\nsquared_error = 69699.347\nsamples = 176429\nvalue = 359.232'),
#  Text(0.0625, 0.3, 'x[5] <= -0.061\nsquared_error = 26375.236\nsamples = 139686\nvalue = 264.392'),
#  Text(0.03125, 0.1, 'squared_error = 14574.633\nsamples = 104179\nvalue = 206.785'),
#  Text(0.09375, 0.1, 'squared_error = 22694.028\nsamples = 35507\nvalue = 433.412'),
#  Text(0.1875, 0.3, 'x[0] <= 0.762\nsquared_error = 70210.233\nsamples = 36743\nvalue = 719.786'),
#  Text(0.15625, 0.1, 'squared_error = 30370.439\nsamples = 28235\nvalue = 623.486'),
#  Text(0.21875, 0.1, 'squared_error = 69512.387\nsamples = 8508\nvalue = 1039.373'),
#  Text(0.375, 0.5, 'x[5] <= 3.876\nsquared_error = 746513.921\nsamples = 4401\nvalue = 1816.939'),
#  Text(0.3125, 0.3, 'x[0] <= 0.074\nsquared_error = 247319.066\nsamples = 3383\nvalue = 1502.323'),
#  Text(0.28125, 0.1, 'squared_error = 145747.696\nsamples = 1396\nvalue = 1136.9'),
#  Text(0.34375, 0.1, 'squared_error = 158950.368\nsamples = 1987\nvalue = 1759.058'),
#  Text(0.4375, 0.3, 'x[5] <= 11.632\nsquared_error = 983368.62\nsamples = 1018\nvalue = 2862.464'),
#  Text(0.40625, 0.1, 'squared_error = 453562.577\nsamples = 986\nvalue = 2740.784'),
#  Text(0.46875, 0.1, 'squared_error = 2794921.118\nsamples = 32\nvalue = 6611.716'),
#  Text(0.75, 0.7, 'x[0] <= 6.157\nsquared_error = 4342939.375\nsamples = 4458\nvalue = 3507.75'),
#  Text(0.625, 0.8, '  False'),
#  Text(0.625, 0.5, 'x[5] <= 3.641\nsquared_error = 1444551.482\nsamples = 3599\nvalue = 2810.625'),
#  Text(0.5625, 0.3, 'x[5] <= 1.453\nsquared_error = 446769.06\nsamples = 2426\nvalue = 2172.375'),
#  Text(0.53125, 0.1, 'squared_error = 299508.544\nsamples = 1742\nvalue = 1926.214'),
#  Text(0.59375, 0.1, 'squared_error = 274460.774\nsamples = 684\nvalue = 2799.293'),
#  Text(0.6875, 0.3, 'x[5] <= 6.601\nsquared_error = 923173.597\nsamples = 1173\nvalue = 4130.656'),
#  Text(0.65625, 0.1, 'squared_error = 284786.896\nsamples = 850\nvalue = 3700.493'),
#  Text(0.71875, 0.1, 'squared_error = 834747.378\nsamples = 323\nvalue = 5262.665'),
#  Text(0.875, 0.5, 'x[0] <= 10.301\nsquared_error = 5919347.854\nsamples = 859\nvalue = 6428.534'),
#  Text(0.8125, 0.3, 'x[5] <= 7.207\nsquared_error = 2771676.039\nsamples = 618\nvalue = 5536.53'),
#  Text(0.78125, 0.1, 'squared_error = 1130539.787\nsamples = 398\nvalue = 4636.561'),
#  Text(0.84375, 0.1, 'squared_error = 1624586.523\nsamples = 220\nvalue = 7164.655'),
#  Text(0.9375, 0.3, 'x[0] <= 14.586\nsquared_error = 6718515.789\nsamples = 241\nvalue = 8715.913'),
#  Text(0.90625, 0.1, 'squared_error = 3979792.823\nsamples = 170\nvalue = 7863.199'),
#  Text(0.96875, 0.1, 'squared_error = 7366450.998\nsamples = 71\nvalue = 10757.623')]
